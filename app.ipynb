# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from unstructured_client import UnstructuredClient
from unstructured_client.models import operations, shared
from unstructured_client.models.errors import SDKError
from IPython.display import JSON
import json
from markdownify import markdownify as md

client = UnstructuredClient(
    api_key_auth="xNQcZcO2UAju3p5Kd9pZjTMnqf9zzr",
    # server_url=DLAI_API_URL,
)

filename = "Pmg_lds.pdf"
with open(filename, "rb") as f:
    files=shared.Files(
        content=f.read(), 
        file_name=filename,
    )

req = shared.PartitionParameters(
    files=files,
    strategy='hi_res',
    pdf_infer_table_structure=True,
    languages=["eng"],
    
)


# Partition the PDF file
resp = client.general.partition(req)
# Out:
# INFO: Preparing to split document for partition.
# INFO: Starting page number set to 1
# INFO: Concurrency level set to 5
# INFO: Determined optimal split size of 20 pages.
# INFO: Document split into 13, 20-paged sets.
# INFO: Partitioning 13, 20-paged sets.
# INFO: Partitioning set #1 (pages 1-21).
# INFO: Partitioning set #2 (pages 21-41).
# INFO: Partitioning set #3 (pages 41-61).
# INFO: Partitioning set #4 (pages 61-81).
# INFO: Partitioning set #5 (pages 81-101).
# INFO: Partitioning set #6 (pages 101-121).
# INFO: Partitioning set #7 (pages 121-141).
# INFO: Partitioning set #8 (pages 141-161).
# INFO: Partitioning set #9 (pages 161-181).
# INFO: Partitioning set #10 (pages 181-201).
# INFO: Partitioning set #11 (pages 201-221).
# INFO: Partitioning set #12 (pages 221-241).
# INFO: Partitioning set #13 (pages 241-244).
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: HTTP Request: POST https://api.unstructured.io/general/v0/general "HTTP/1.1 200 OK"
# INFO: Successfully partitioned set #1, elements added to the final result.
# INFO: Successfully partitioned set #2, elements added to the final result.
# INFO: Successfully partitioned set #3, elements added to the final result.
# INFO: Successfully partitioned set #4, elements added to the final result.
# INFO: Successfully partitioned set #5, elements added to the final result.
# INFO: Successfully partitioned set #6, elements added to the final result.
# INFO: Successfully partitioned set #7, elements added to the final result.
# INFO: Successfully partitioned set #8, elements added to the final result.
# INFO: Successfully partitioned set #9, elements added to the final result.
# INFO: Successfully partitioned set #10, elements added to the final result.
# INFO: Successfully partitioned set #11, elements added to the final result.
# INFO: Successfully partitioned set #12, elements added to the final result.
# INFO: Successfully partitioned set #13, elements added to the final result.
# INFO: Successfully partitioned the document.

# %%
print(json.dumps(resp.elements,indent=2))
# Out:
# [
#   {
#     "type": "Image",
#     "element_id": "901619d822b1fd84233b99cf7dbf2083",
#     "text": "A Guide to Missionary Service  Preach My Gospel  (D&C 50:14) ",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "0037e5e74d4951594c8c8a99714dce52",
#     "text": "A Guide to Missionary Service",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "c7b9347d5636f1bd64df9179ff2a5cd1",
#     "text": "Preach My Gospel",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "d0dfb6cb26ac0e4d35fe4c41c55ec8f7",
#     "text": "(D&C 50:14)",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "parent_id": "c7b9347d5636f1bd64df9179ff2a5cd1",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ac603c2589068be90fc9c7e3462dad1d",
#     "text": "\u201cRepent, all ye ends of the earth, and come unto me and be baptized in my name,",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "parent_id": "c7b9347d5636f1bd64df9179ff2a5cd1",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "0e72680a1f3ce45a3b12f8e69309399a",
#     "text": "that ye may be sanctified by the reception of the Holy Ghost\u201d (3 Nephi 27:20).",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 1,
#       "parent_id": "c7b9347d5636f1bd64df9179ff2a5cd1",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "defae5010130f8702c9db9ea6ea88d26",
#     "text": ".-",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "parent_id": "c7b9347d5636f1bd64df9179ff2a5cd1",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "d55291e5e7998419089a9bd3477e1553",
#     "text": "LML HE U HHPR",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "07283861600d7f46a902ba889424a0ac",
#     "text": "Name: Mission and Dates of Service: List of Areas: Companions:",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e45b4617263882c0abd395284216357d",
#     "text": "Names and Addresses of People Baptized and Confirmed:",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 2,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "323b50aa8fe37e8470fcf99d48e9b6d2",
#     "text": "e - o hybojnnnhn-",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 3,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "b13ec509fb9bfb37ec127d2b3b0915bb",
#     "text": "Preach My Gospel (D&C 50:14)",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 3,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "8554ed43353b77240f597f0ac23ae1f7",
#     "text": "Published by The Church of Jesus Christ of Latter-day Saints Salt Lake City, Utah",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 3,
#       "parent_id": "b13ec509fb9bfb37ec127d2b3b0915bb",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "6a118d09ebb30f6523cd8c217c71cd66",
#     "text": "",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 4,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "c649c4bf5e7f8cd6accf35c380c8800d",
#     "text": "Cover: John the Baptist Baptizing Jesus \u00a9 1988 by Greg K. Olsen Courtesy Mill Pond Press and Dr. Gerry Hooper. Do not copy.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 4,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "c9904d5db7730d625dd260cdc978e9e1",
#     "text": "\u00a9 2004 by Intellectual Reserve, Inc. All rights reserved",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 4,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "82b9be442763c9cff03773dcaf51449a",
#     "text": "Printed in the United States of America English approval: 01/05",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 4,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "71a54159440940d15e816b25c16af895",
#     "text": "e - o hybojnnnhn-",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 5,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "e215f5cdda0e787e5d4d85ad3ed0dede",
#     "text": "Preach My Gospel (D&C 50:14)",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 5,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Table",
#     "element_id": "6af66324f8b0cbc86e2cd076773f7fc2",
#     "text": "First Presidency Message . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . v Introduction: How Can I Best Use Preach My Gospel? . . . . . . . . . . . . . . . . . . . . . . vii 1 What Is My Purpose as a Missionary? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 1 2 How Do I Study Effectively and Prepare to Teach? . . . . . . . . . . . . . . . . . . . . . . . . . 17 3 What Do I Study and Teach? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 29 \u2022 Lesson 1: The Message of the Restoration of the Gospel of Jesus Christ . . . . . . . 31 \u2022 Lesson 2: The Plan of Salvation . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 47 \u2022 Lesson 3: The Gospel of Jesus Christ . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 60 \u2022 Lesson 4: The Commandments . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 71 \u2022 Lesson 5: Laws and Ordinances . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 82 4 How Do I Recognize and Understand the Spirit? . . . . . . . . . . . . . . . . . . . . . . . . . . 89 5 What Is the Role of the Book of Mormon? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 103 6 How Do I Develop Christlike Attributes? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 115 7 How Can I Better Learn My Mission Language? . . . . . . . . . . . . . . . . . . . . . . . . . 127 8 How Do I Use Time Wisely? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 137 9 How Do I Find People to Teach? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 155 10 How Can I Improve My Teaching Skills? . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 175 11 How Do I Help People Make and Keep Commitments? . . . . . . . . . . . . . . . . . . . 195 12 How Do I Prepare People for Baptism and Confirmation? . . . . . . . . . . . . . . . . . 203 13 How Do I Work with Stake and Ward Leaders? . . . . . . . . . . . . . . . . . . . . . . . . . . 213 Index . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . 225",
#     "metadata": {
#       "text_as_html": "<table><tbody><tr><td></td><td>First Presidency Message</td><td></td></tr><tr><td></td><td>Introduction: How Can I Best Use Preach My Gospel?</td><td>vii</td></tr><tr><td></td><td>What Is My Purpose as a Missionary? ....................................</td><td>1</td></tr><tr><td></td><td>How Do I Study Effectively and Prepare to Teach? .........................</td><td>17</td></tr><tr><td rowspan=\"5\"></td><td>What Do I Study and Teach?</td><td>29</td></tr><tr><td>\u00a2 Lesson 1: The Message of the Restoration of the Gospel of Jesus Christ</td><td>31</td></tr><tr><td>\u00a2 Lesson 2: The Plan of Salvation</td><td>47</td></tr><tr><td>\u00a2 Lesson 3: The Gospel of Jesus Christ</td><td>60</td></tr><tr><td>\u00a2 Lesson 4: The Commandments</td><td>71</td></tr><tr><td></td><td>* Lesson 5: Laws and Ordinances</td><td>82</td></tr><tr><td></td><td>How Do I Recognize and Understand the Spirit? ..........................</td><td>89</td></tr><tr><td></td><td>What Is the Role of the Book of Mormon? . .............. ... ...</td><td>103</td></tr><tr><td></td><td>How Do I Develop Christlike Attributes?</td><td>115</td></tr><tr><td></td><td>How Can I Better Learn My Mission Language?</td><td>127</td></tr><tr><td></td><td>How Do I Use Time Wisely? ..................... ... ...,</td><td>137</td></tr><tr><td></td><td>How Do I Find People to Teach?</td><td>155</td></tr><tr><td>10</td><td>How Can I Improve My Teaching Skills? ................................</td><td>175</td></tr><tr><td>11</td><td>How Do I Help People Make and Keep Commitments? ...................</td><td>195</td></tr><tr><td>12</td><td>How Do I Prepare People for Baptism and Confirmation?</td><td>203</td></tr><tr><td rowspan=\"2\">13</td><td>How Do I Work with Stake and Ward Leaders? ..........................</td><td>213</td></tr><tr><td>Index</td><td>225</td></tr></tbody></table>",
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 5,
#       "parent_id": "e215f5cdda0e787e5d4d85ad3ed0dede",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "PageNumber",
#     "element_id": "402b6e348e147c4af0de7d68b0c29d34",
#     "text": "iii",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 5,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "2262e537d7a918f4fddc384d61f9cba3",
#     "text": "",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 6,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "eed099bae9e22613d963f00975287fba",
#     "text": "e - o hybojnnnhn-",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "4a5bfc23264f637a98c88e8d9a080bc1",
#     "text": "First Presidency Message",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "7bf300dd932db388524e7552b095093e",
#     "text": "Dear Fellow Missionary:",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "06f6f854533bf3088d7392b022a4db07",
#     "text": "We compliment you on the great opportunity you have to be a missionary. There is no more compelling work than this, nor any which brings greater satisfaction.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "parent_id": "7bf300dd932db388524e7552b095093e",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "912197d1c403fbe5b33578b68d32ffd4",
#     "text": "Preach My Gospel is intended to help you be a better-prepared, more spiritually mature missionary and a more persuasive teacher. We urge you to use it daily in your personal and companion preparation, and in your district meetings and zone conferences. Study the referenced scriptures and learn the doctrines and principles.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "parent_id": "7bf300dd932db388524e7552b095093e",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "7e52beafc8958fc4e4fed8f56db23196",
#     "text": "We challenge you to rise to a new sense of commitment to assist our Father in Heaven in His glorious work. Every missionary has an important role in helping \u201cto bring to pass the immortality and eternal life of man\u201d (Moses 1:39).",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "parent_id": "7bf300dd932db388524e7552b095093e",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ab4dfb8a9fbb254e50e71689479a0246",
#     "text": "The Lord will reward and richly bless you as you humbly and prayerfully serve Him. More happiness awaits you than you have ever experienced as you labor among His children.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "parent_id": "7bf300dd932db388524e7552b095093e",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "93caf73623958ceab6c8254aca5ff90e",
#     "text": "The First Presidency",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "parent_id": "7bf300dd932db388524e7552b095093e",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "6d46bf65729519545c0bff34a37ad0b6",
#     "text": "v",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 7,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "350d889865cd4dd0249d664dba9b2a19",
#     "text": "",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 8,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "6ad5794fd8f048e1dc4440717a20ce7b",
#     "text": "Introduction",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "1d2b2aa6bda615db73b09b82a5b47e60",
#     "text": "Introduction: How Can I Best Use Preach My Gospel?",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "bca938b315d51e56ddce9713ec880d0b",
#     "text": "Notes",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "parent_id": "1d2b2aa6bda615db73b09b82a5b47e60",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "1409aca9089fa82f9a76c86f4f90e2b6",
#     "text": "Preach My Gospel",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ce54b617db437c11db4132f20a450314",
#     "text": "missionary. You can spend an entire study session on just a few paragraphs\u2014or an entire chapter. You can study chapters in order or plan another sequence that better meets your needs. This flexibility allows you to study what you need when you need it and as directed by your mission president.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "parent_id": "1409aca9089fa82f9a76c86f4f90e2b6",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e1b54df14eb592afbf4cc5773753f4f0",
#     "text": "All of the chapters in Preach My Gospel will help prepare you to fulfill your purpose as a missionary. However, as you begin to study chapter 3, you may sense a difference in approach. Most of the chapters are addressed to you. Chapter 3 is addressed to a more general audience. You learn the doctrines in chapter 3 (a) to strengthen your own gospel knowledge and testimony and (b) to teach others and prepare them to make and keep commitments and covenants.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "parent_id": "1409aca9089fa82f9a76c86f4f90e2b6",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "5285676ea12d1a1bc87121b57d8da54e",
#     "text": "Preach My Gospel pre A g,",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "eb99396ffadc7d4599e8982dbaca3399",
#     "text": "The doctrines in some of the other chapters may also help you teach investigators and new members. For example, chapter 4, \u201cHow Do I Recognize and Understand the Spirit?\u201d may help you teach some investigators about how to gain a testimony by the power of the Holy Ghost. Chapter 5, \u201cWhat Is the Role of the Book of Mormon?\u201d may help you resolve an investigator\u2019s concerns about reading the Book of Mormon. Ideas from chapter 2, \u201cHow Do I Study Effectively and Prepare to Teach?\u201d may help new converts gain more from their study of the Book of Mormon.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "6b9e4fd5677ed176c396c4b21b9e1dee",
#     "text": "Preach My Gospel focuses on the fundamentals of missionary work. It does not answer every question or situation you will encounter. You will be most effective as you follow the Spirit, search the scriptures, keep the commandments, and apply what you learn.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "52198fe95da12a1390ba4401dd40961c",
#     "text": "Study the chapters throughout your mission. Apply what you learn. Evaluate your work. Missionaries who strive to prepare themselves daily and seek to improve regularly will receive direction from the Holy Ghost and see blessings in their lives.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "41077cb8becf10a7bd5895f96607ed61",
#     "text": "The Missionary Lessons",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "eb04cba33c2381a55c0741f72963f1d3",
#     "text": "You have the flexibility to teach the lessons in whatever way best helps people fully prepare for their baptism and confirmation. Your purpose is not only to cover the material; it is to help others come unto Christ through faith in Jesus Christ, repentance, baptism, receiving the gift of the Holy Ghost, and enduring to the end. Rarely should a lesson go over 45 minutes. You may find that time may only allow shorter teaching visits. In this case, you may need frequent, short teaching visits covering smaller portions of material.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "parent_id": "41077cb8becf10a7bd5895f96607ed61",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "cfe4ad29ca08885c664debd0b4d7d0ef",
#     "text": "You can teach the lessons in many ways. Which lesson you teach, when you teach it, and how much time you give to it are best determined by the needs of the investigator and the direction of the Spirit. Do not memorize the entire lesson.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "parent_id": "41077cb8becf10a7bd5895f96607ed61",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "4d07e29521252a10eeb75861e1471c55",
#     "text": "vii",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 9,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "6eac8163bdd71c8b77e1c8c2b5ed90c7",
#     "text": "Introduction",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "4d07e29521252a10eeb75861e1471c55",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "16cb3fa6ab3dbfb0d892436c982436fe",
#     "text": "Notes",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "4d07e29521252a10eeb75861e1471c55",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "f95ca3b72327a36c63ea73a4dca45f36",
#     "text": "Personal Study, Companion Study, District Meetings, and Zone Conferences",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "995dd2f7d58df2d56ab69837164b24e8",
#     "text": "Effective study during your mission will help you fulfill your purpose as a missionary and strengthen your testimony of the gospel of Jesus Christ. Four of your most important study opportunities are personal study, companion study, district meetings, and zone conferences. Your daily schedule includes time for personal and companion study every day.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f95ca3b72327a36c63ea73a4dca45f36",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#     "text": "Missionary Daily Schedule*",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "47830b8f408718f2aa3066fddf31697d",
#     "text": "6:30 a.m. Arise, pray, exercise (30 minutes), and prepare for the day.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "a74bc29adcef96a6264e8b417aff09fa",
#     "text": "7:30 a.m. Breakfast.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "cc7b16c6c417a4ebe0afed4a052b2ed1",
#     "text": "8:00 a.m. Personal study: the Book of Mormon, other scriptures, doctrines of the missionary lessons, other chapters from Preach My Gospel, the Missionary Handbook, and the Missionary Health Guide.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "d60a089499cc84a8a30aa80162a7280e",
#     "text": "9:00 a.m. Companion study: share what you have learned during personal study, prepare to teach, practice teaching, study chapters from Preach My Gospel, confirm plans for the day.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "b9ec649fbdb23bfc9eb292f31cea176a",
#     "text": "10:00 a.m. Begin proselyting. Missionaries learning a language study that language for an additional 30 to 60 minutes, including planning language learning activities to use during the day.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "433ca3840ba4300703893b76a9d53130",
#     "text": "Missionaries may take an hour for lunch and additional study, and an hour for dinner at times during the day that fit best with their proselyting. Normally dinner should be finished no later than 6:00 p.m.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "cc4a594fa6ce217ca4374753b2b8c7c6",
#     "text": "9:00 p.m. Return to living quarters (unless teaching a lesson; then return by 9:30) and plan the next day\u2019s activities (30 minutes). Write in journal, prepare for bed, pray.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "a19ac655226d71359559fc8776564d58",
#     "text": "10:30 p.m. Retire to bed.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "48ddb1152eb4a1af6387208e596d7eda",
#     "text": "*In consultation with the Presidency of the Seventy or the Area Presidency, your mission president may modify this schedule to meet local circumstances.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "9b37e414b85f5db99713368394b6d9f4",
#     "text": "in companion study, district meeting, and zone conferences, where you can \u201cteach one another the doctrine of the kingdom\u201d (D&C 88:77). What you gain from your study sessions and district meetings will help you teach with spiritual power.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "f21989fa3ac1d4c8d55cf5c42ff641cf",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "9e12099eabf47b317bf86f3159e73261",
#     "text": "Personal Study",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "abaaaae5572e5b732c50c45639af8a83",
#     "text": "your knowledge and testimony of the restored gospel and help you prepare to meet the needs of those you teach. In your personal study, focus on the standard works and the approved missionary library:",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "9e12099eabf47b317bf86f3159e73261",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "e7977ed62a7c728b7bc6d3f89bdf7215",
#     "text": "Jesus the Christ",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "9e12099eabf47b317bf86f3159e73261",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "be8113f93996101daae7c7b8a80333b2",
#     "text": "\u2022 Our Heritage",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "9e12099eabf47b317bf86f3159e73261",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "27609d2cf88f9b71cde6c324e1fdf4c0",
#     "text": "\u2022 Our Search for Happiness",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "9e12099eabf47b317bf86f3159e73261",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "fd744d541b8ac4fb8339d395a4c46195",
#     "text": "True to the Faith",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "parent_id": "9e12099eabf47b317bf86f3159e73261",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "dbde51333d7337ca094b1d660d127e05",
#     "text": "$\\\u201c0\u2018 o m\"\u201dq\ufb01,, & % & g Eii \u00ae2hing tne Les*\u2122",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "PageNumber",
#     "element_id": "bf3ad55383e6fb8943521782637e91b7",
#     "text": "viii",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 10,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "c238b1d48ed0a2462b000f22418e2f3f",
#     "text": "Introduction",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "a06a9789cafe7a7cb9bfa975cb29edba",
#     "text": "You can make personal study effective as you:",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "2ce81fcbeba44459aefbb2d810caae31",
#     "text": "\u2022 Read from the Book of Mormon and other scriptures.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "1e8143fdb46e4d31afc7f90dcd848045",
#     "text": "\u2022 Study the doctrines of the missionary lessons.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "0f2986396b34824bcf6a4110b1713197",
#     "text": "\u2022 Study other chapters from Preach My Gospel.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "e24a91cd4945da12acd5afadd847967c",
#     "text": "Companion Study",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "95520d31c3152af6bc1104ab27e36899",
#     "text": "The purpose of companion study is to (1) build unity in your companionship in order to teach by the Spirit and (2) focus on the progress of those you teach. You can make companion study effective as you:",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "e24a91cd4945da12acd5afadd847967c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "0b044118359df2d2765c44c357fd4b49",
#     "text": "\u2022 Share insights with each other from personal study.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "e24a91cd4945da12acd5afadd847967c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "7b7ceabb9bbaf52b7b3efaa5ec22de52",
#     "text": "\u2022 Prepare for specific teaching appointments, member visits, finding opportunities, and other activities. Study material that helps you teach, find, and work more effectively. Discuss the people with whom you are working. Make plans to apply what you are learning.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "e24a91cd4945da12acd5afadd847967c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "4adba0f22824c37f2534bd0bfc0aa331",
#     "text": "\u2022 Throughout the day, continue to discuss the principles, goals, skills, and plans from companion study.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "e24a91cd4945da12acd5afadd847967c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "2f9904e4161136224a0a8e99c6de0b91",
#     "text": "District Meetings",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "4e14637d2e6f0ef0e5e4a3e04421a7f8",
#     "text": "The purpose of district meeting is to \u201cteach one another the doctrine of the kingdom\u201d (D&C 88:77).",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "6ebcc43d850096820c2aeac431926b09",
#     "text": "\u2022 District meetings are held each week for 60 to 90 minutes.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "308fff6a4ffa08e009d1996351a49db3",
#     "text": "\u2022 The district leader plans and conducts the district meeting and may invite other missionaries to help teach.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "57854e7e1498a89ac0761baa924b0a67",
#     "text": "\u2022 District meetings may include:",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "9e96091f0c9533532701e9e538628d59",
#     "text": "\u2013 Sharing insights from personal and companion study.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "49889565c02004fc569e5e7bf312542a",
#     "text": "\u2013 Practicing the lessons in various settings.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "88abc9a075bd8bc1b5a92f11e4a676f8",
#     "text": "\u2013 Explaining, demonstrating, and practicing principles and skills described in Preach My Gospel.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f7e9ace0afc1033622d7de86485eef75",
#     "text": "\u2013 Discussing the progress and needs of investigators.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "c086591f4bdd6fabba86b8f51794a559",
#     "text": "\u2013 Discussing and addressing challenges in the district.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "949b87e4e01d33a847f47d23d11a3001",
#     "text": "\u2013 Sharing experiences and testimonies of missionary work.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "04ccb852ed8f9d91baf2487be4581cd8",
#     "text": "\u2022 District leaders may use district meeting to receive reports regarding the efforts of missionaries in the district. They should not set goals or quotas for other missionaries.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "2f9904e4161136224a0a8e99c6de0b91",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "aec070b28d24ba8f993c787fd4929731",
#     "text": "Zone Conferences",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "67396e9cba23d2be1e40231120db44d4",
#     "text": "Zone conferences are held under the direction of the mission president.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "aec070b28d24ba8f993c787fd4929731",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "bcf32beebb1b98e36bbe82fdae7a51f8",
#     "text": "Features of Preach My Gospel",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "c4205728182b04132eef20f935bd9d8e",
#     "text": "Each chapter in Preach My Gospel has several features. These features should help you get more from your study\u2014not force you to learn a certain way. Use these features in a flexible manner based on your needs.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "parent_id": "bcf32beebb1b98e36bbe82fdae7a51f8",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Header",
#     "element_id": "f7e746558fcbdc9ebc2beafc2c4c01ac",
#     "text": "Notes",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "PageNumber",
#     "element_id": "5d8dd3df81eefa4d36f9168cd7c2bda2",
#     "text": "ix",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 11,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "5b543d03d243d7392f2df46cb1354d9b",
#     "text": "Introduction",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "4f24c952ab896791fcb934ebf76cc7b4",
#     "text": "Notes",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "parent_id": "5b543d03d243d7392f2df46cb1354d9b",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "3bb8ebeaf0c42b0231466847d3cf8fb6",
#     "text": "Study Journal",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "eb10793f7cdc21b0010f31e0990f02e0",
#     "text": "Preach My Gospel frequently asks that you use a study journal to help you understand, clarify, and remember what you are learning. Elder Richard G. Scott taught, \u201cKnowledge carefully recorded is knowledge available in time of need. Spiritually sensitive information should be kept in a sacred place that communicates to the Lord how you treasure it. This practice enhances the likelihood of your receiving further light\u201d (\u201cAcquiring Spiritual Knowledge,\u201d Ensign, Nov. 1993, 86). Review your study journal to recall spiritual experiences, see new insights, and recognize your growth.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "parent_id": "3bb8ebeaf0c42b0231466847d3cf8fb6",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "530d929bf75adc48b3516ab956070ff3",
#     "text": "your thoughts and impressions in a way that fits how you learn. Develop your own system to easily access key information in the future. Use it often to review, access, and apply what you have learned. Use your study journal to take notes and record impressions during your personal and companion study, district meetings, zone conferences, and interviews with the mission president.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "parent_id": "3bb8ebeaf0c42b0231466847d3cf8fb6",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "b87c3200898dfe6b3e57cdcd30bc785c",
#     "text": "Information Boxes",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "b8255832fa14f803c508ece1b2399fef",
#     "text": "The boxes in Preach My Gospel will help you learn. Some boxes preview or summarize key points. Others help you focus your study, learn from the scriptures, apply what you learn, develop your abilities, and meet the needs of those you teach. In most cases, these boxes are simply a starting point. Prayerfully build on the activities in the boxes by developing new study activities and searching additional scriptures.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "parent_id": "b87c3200898dfe6b3e57cdcd30bc785c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "fe68c44a2e1f39752c4f952ef780c3cc",
#     "text": "\u201cConsider This.\u201d Most chapters begin with questions in a \u201cConsider This\u201d box. These questions focus on the key points of the chapter and provide a framework for your study. Use these questions to organize, understand, ponder, and apply what you learn.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "parent_id": "b87c3200898dfe6b3e57cdcd30bc785c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "205d26455fd93c78cb66302a1c165947",
#     "text": "\u201cRemember This.\u201d Most chapters end with a \u201cRemember This\u201d box\u2014a summary of the most important points from the chapter. As you finish studying a chapter, review these statements to ensure you understand these main points. Evaluate how well you are applying these points, and make plans to apply what you have learned.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "parent_id": "b87c3200898dfe6b3e57cdcd30bc785c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e7805c37ee7808d4f5582133ae495224",
#     "text": "\u201cScripture Study.\u201d These boxes direct you to references that can build your understanding and testimony. Build on these references by searching for additional scriptures. Ask yourself additional related questions that will help you gain insight and apply what you learn.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "parent_id": "b87c3200898dfe6b3e57cdcd30bc785c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "3c9c3301ab1515a89eb61c42c2c63695",
#     "text": "\u201cActivity.\u201d Most chapters have activities for personal and companion study to enhance your learning and application. Repeat these activities throughout your mission. You will gain new insights each time you do because your needs\u2014and the needs of those you are teaching\u2014will change.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 12,
#       "parent_id": "b87c3200898dfe6b3e57cdcd30bc785c",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "1d334c451b95a3d27e1706ef4e154f30",
#     "text": "Consider This",
# ...
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "7bf5f40a94d18ba697d6a0eafbc8df62",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "f718e6a2013e9bf80fb2eb5739d53f29",
#     "text": "Taylor, John, on teaching simply, 182 Teaching Record, form described, 141\u201342 Teaching, adjust to meet needs, 177\u201378",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "7bf5f40a94d18ba697d6a0eafbc8df62",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "300d02a822455a8d6b0eeb2a473d288b",
#     "text": "and finding, 158\u201359 and listening, 185\u201386 and memorization, vii by the Spirit, 3\u20134",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "7bf5f40a94d18ba697d6a0eafbc8df62",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "aa669b52a7fb2aa743688c3f444dc38b",
#     "text": "First Presidency counsel on, 175\u201376",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "7bf5f40a94d18ba697d6a0eafbc8df62",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "a0bc896493de6a80fd1e05de7ec0a950",
#     "text": "how to begin, 176\u201377 in a Church calling, 88 length of appointments, 178 length of lessons, vii people without a Christian background, 190\u201391 the gospel as a missionary, 175 with companion, 178\u201379 with members, 179 with questions, 183\u201384 with scriptures, 180\u201382",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "7bf5f40a94d18ba697d6a0eafbc8df62",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "6fa17195ea5b312f8c25ad6abba0967a",
#     "text": "Telestial kingdom, 53 Temples, worship in, 86 Ten Commandments, obedience to, 76\u201377 Terrestrial kingdom, 53 Testimony, bear frequently, 198\u201399 Time use, effective, 137 Tithes and offerings, donating, 80 Tithing, law of, 79 Tongues, gift of, 133 Tree of life, activity, 2 True to the Faith, 21 Tyndale, William, 45",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "7bf5f40a94d18ba697d6a0eafbc8df62",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "706a6d4c938025a62475730ff0c9567b",
#     "text": "V",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "5bcbed5d02bc73c8448d1c4d6132970e",
#     "text": "Virtue, 118\u201319 Visiting teaching, 215",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "a25acbf3fd6cf2420ed9c133426c82d8",
#     "text": "W",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "e62801dcd297701fb6d0b72e7b09f8e6",
#     "text": "Ward council, 149\u201350, 215\u201317",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "a25acbf3fd6cf2420ed9c133426c82d8",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "993d1fed6a22d2e14d7ace3e45240df4",
#     "text": "and friendship of new converts, 216 and helping new converts serve in callings, 217 and nourishing new converts, 217\u201318 responsible to fellowship, 214",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "a25acbf3fd6cf2420ed9c133426c82d8",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "da6eb3364dc5f96873f5bbd64bf5a04d",
#     "text": "Ward leaders, and missionary work, 213",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "a25acbf3fd6cf2420ed9c133426c82d8",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "55f6a17edda4b20e2d5f9627e68a4c9f",
#     "text": "duties of, 217",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "a25acbf3fd6cf2420ed9c133426c82d8",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "2e96333e265ed5c0815b868560cd4f2a",
#     "text": "Ward mission leader, duties of, 218\u201319 Ward mission plan, 220 Ward missionaries, duties of, 219",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "a25acbf3fd6cf2420ed9c133426c82d8",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "d374898ae9951175d15567c44b48e8fb",
#     "text": "how to use Preach My Gospel, xi",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "a25acbf3fd6cf2420ed9c133426c82d8",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "ac335f20f23ac7acdcdc19f0421e7fa0",
#     "text": "Weekly planning session, how to hold, 147\u201350 Wirthlin, Joseph B., on using the Book of",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "a25acbf3fd6cf2420ed9c133426c82d8",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "6d71e372a071e1458626dde164d3221f",
#     "text": "Mormon, 110 Word of Wisdom, 78 Wycliffe, John, 45",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "67d8d332eef460ed1bc2e4c4600799eb",
#     "text": "Y",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "316e5729a8cd13b6f0a0bd2194ec93bf",
#     "text": "Young Men, organization, 84 Young Women, organization, 84 Young, Brigham, on receiving testimony, 199",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "67d8d332eef460ed1bc2e4c4600799eb",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "cf310fae48b15a9f666001c863242129",
#     "text": "Z",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "7a0da82c0dcd2e45c664dc002a363b19",
#     "text": "Zone conference, and study, viii",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "parent_id": "cf310fae48b15a9f666001c863242129",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "PageNumber",
#     "element_id": "84414178e0fa1d486494466ec1ae94bd",
#     "text": "228",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 242,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#     "text": "Remember This. . .",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "f18bc7ca1cd721170eb7e9099bf7f235",
#     "text": "Your purpose is to bring souls to Christ. \u2022 Prepare people to meet the qualifications for baptism in Doctrine and Covenants 20:37 and the baptismal interview questions.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "a0c5995ffe08eeeffaafdac59d78a1b6",
#     "text": "Pray often for yourself and for others. \u2022 Rely on the Spirit to show you where to go, what to do, and what to say. \u2022 Be exactly obedient. \u2022 Study the language of your mission each day.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "9889fa119267a0977ae3b535b0ba6012",
#     "text": "Plan every day and focus on the key indicators. \u2022 Work effectively all day, every day.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "7717648959dbbca9baca33355b600b23",
#     "text": "Ask for referrals from everyone! \u2022 Teach when you find; find when you teach.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "803bd097663c0cf5886e3e2b9bf80f77",
#     "text": "Read the Book of Mormon with those you teach. \u2022 Teach people that an important way to know that Joseph Smith is a prophet of God is to read and pray about the Book of Mormon.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "ListItem",
#     "element_id": "fc361d4a1a73319294d1783acbe470fa",
#     "text": "Contact every investigator daily. \u2022 Bear testimony frequently. \u2022 Have a member at every lesson possible. \u2022 Always set specific dates and times for the next lesson. \u2022 Invite all investigators to baptismal services. \u2022 After each lesson, provide investigators with something to read and",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "5c679df539a806e39bc5f6fbe8aaf07d",
#     "text": "ponder in preparation for the next meeting.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "2fc85b2640e37fbd4c17ec3331b0a050",
#     "text": "\u2022 Build relationships with members by serving them and working with the leadership of the ward.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "c0808c2a3cd256d7fc7276fb480a8f1b",
#     "text": "\u2022 Help ward leaders with retention and activation activities.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "79d47c8ddd0140f0bb5868131cc1f9ca",
#     "text": "\u2022 Help everyone you teach make commitments that will bring about",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "00de5f52b0eafc81d7aca7e2bb402dd9",
#     "text": "repentance and will strengthen their faith in the Savior. \u2022 Love the Lord and serve Him the very best you can.",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "parent_id": "2be745b5c0a960e32b9d2d76fad8bf2a",
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "5dadbac878a21ac32918a3eefb775839",
#     "text": "U",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 243,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "1b493510ebfdc7162948b3b8b85ffea4",
#     "text": "THE CHURCH OF JESUS CHRIST OF LATTER-DAY SAINTS",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 244,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "NarrativeText",
#     "element_id": "9c5b03da55d5f94ce17a9fc0995edde6",
#     "text": "OF LATTER-DAY SAINTS",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 244,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "5da5564c61eed352198311f7a5544655",
#     "text": "4",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 244,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Title",
#     "element_id": "098f0a301fb98816c9338a62817e344f",
#     "text": "ENGLISH",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 244,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "Image",
#     "element_id": "4ae4e146ec12209c569a34600444de50",
#     "text": "AR",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 244,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "8073f171637615c6a9720603ef0abd15",
#     "text": "02366 17000",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 244,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "35b1e56a83b0931d0f6eca6b7369da46",
#     "text": "36617",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 244,
#       "filename": "Pmg_lds.pdf"
#     }
#   },
#   {
#     "type": "UncategorizedText",
#     "element_id": "b552c9f3672741b37f39a5089924c955",
#     "text": "5",
#     "metadata": {
#       "filetype": "application/pdf",
#       "languages": [
#         "eng"
#       ],
#       "page_number": 244,
#       "filename": "Pmg_lds.pdf"
#     }
#   }
# ]

# %%
# JSON(json.dumps(resp.elements, indent=2))
keys = set()
for element in resp.elements:
    keys.add(element['type'])
print(keys)
# Out:
# {'Header', 'UncategorizedText', 'PageNumber', 'ListItem', 'NarrativeText', 'Title', 'Table', 'Image'}

# %%
# convert dictionary elements to html tags - transform to markdown
# with markdownify

def format_to_html(content):
    if content['type'] == 'Header':
        header = content['text']
        return f"<h2>{header}</h2>\n\n"
    
    elif content['type'] == 'UncategorizedText':
        return f"<span>{content['text']}</span>\n\n"
    
    elif content['type'] == 'PageNumber':
        page_number = content['text']
        return f"<span>{page_number}</span>\n\n"
    
    elif content['type'] == 'ListItem':
        list_items = content['text']
        return f"<ul><li>{list_items}</li></ul>\n\n"
    
    elif content['type'] == 'NarrativeText':
        return f"<p>{content['text']}</p>\n\n"
    
    elif content['type'] == 'Title':
        return f"<h1>{content['text']}</h1>\n\n"
    
    elif content['type'] == 'Table':
        value = content['metadata']
        return f"{value['text_as_html']}\n\n"
    
    elif content['type'] == 'Image':
        alt_text = content['metadata']
        return f"<img src='#' alt='see page {alt_text['page_number']}' />\n\n"
    
    else:
        return ""


# function to write to markdown file
def save_to_markdown(text, markdown_file):
    with open(markdown_file, 'w', encoding='utf-8') as f:
        f.writelines(text)

# %%
# iterate through the response and format
html_tags = ""

for element in resp.elements:
    html_tags += format_to_html(element)

#convert to markdown using markdownify
md_content = md(html_tags)

# save to markdown file
save_to_markdown(md_content, 'Pmg_lds.md')
